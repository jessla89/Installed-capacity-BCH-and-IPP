# %%
import pandas as pd
import altair as alt

# %%
data = pd.read_csv('IPP_committed.csv')

# %%
data
# Out:
#                     Project_Name  \
# 0            Ulkatcho Solar Farm
# 1          Brewster Wind Project
# 2     Stewart Creek Wind Project
# 3    Nithi Mountain Wind Project
# 4                K2 Wind Project
# 5                  quA-ymn Solar
# 6   Highland Valley Wind Project
# 7       Mount Mabel Wind Project
# 8    ShTSaQU Solar Project Logan
# 9   Boulder-Elkhart Wind Project
# 10                 ONA UNB Solar
# 11      Nilhts'I Ecoener Project
# 12           Taylor Wind Project
#
#                                              Owner        Location   Type  \
# 0              Ulkatcho Energy Limited Partnership     Anahim Lake  Solar
# 1                                Brewster Wind Inc  Campbell River   Wind
# 2                         Stewart Creek Power Inc.   Fort St. John   Wind
# 3         Nithi Mountain Power General Partnership     Fraser Lake   Wind
# 4                               K2 Wind Power Inc.         Kelowna   Wind
# ...

# %%
data['Capacity(MW)'].sum()
# Out:
# 1668.8000000000002

# %%
data['Energy(GWh/yr)'].sum()
# Out:
# 4886.0
